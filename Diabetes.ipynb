# %% [markdown]
# <a href="https://colab.research.google.com/github/igorgcgv/igorgcgv/blob/main/Diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Configurando o Ambiente de Trabalho

# %%
# !pip install -q pandas==1.2.4
# !pip install  -q ipython-sql

import pandas as pd
import sqlite3

# %%
#Criando uma conexão com o banco de dados
cnn = sqlite3.connect ('diabetes.db')

# %%
#Problema de negócio:

#Temos em mãos um arquivo com dados de pacientes que desenvolveram ou não diabetes.
#Precisamos gerar uma amostra de dados com os pacientes com mais de 50 anos
#e para cada um deles indicar em uma nova coluna se o paciente está normal
#(BMI menor que 30) ou obeso (BMI maior ou igual a 30).
#Então devemos gerar um novo arquivo CSV e encaminhar para o Cientista de Dados.

# %%
#Criando uma conexão com o banco de dados
cnn = sqlite3.connect ('diabetes.db')
cursor = cnn.cursor ()

# %%
#Fazendo a carga das tabelas (datasets)
dados = pd.read_csv ('/content/diabetes.csv', sep =',', error_bad_lines=False)

# %%
#Transformando o DataFrame em SQL para armazenar no banco de dados criado acima!
dados.to_sql('dados', cnn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-a8fde139d160> in <module>
#       1 #Transformando o DataFrame em SQL para armazenar no banco de dados criado acima!
# ----> 2 dados.to_sql('dados', cnn)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2777         from pandas.io import sql
#    2778
# -> 2779         sql.to_sql(
#    2780             self,
#    2781             name,
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     599         )
#     600
# --> 601     pandas_sql.to_sql(
#     602         frame,
#     603         name,
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1869             dtype=dtype,
#    1870         )
# -> 1871         table.create()
#    1872         table.insert(chunksize, method)
#    1873
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/sql.py in create(self)
#     736         if self.exists():
#     737             if self.if_exists == "fail":
# --> 738                 raise ValueError(f"Table '{self.name}' already exists.")
#     739             elif self.if_exists == "replace":
#     740                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'dados' already exists.

# %%
#Visualizando a tabela criada

consulta_1 = """
SELECT
  *
FROM
  dados


"""
#Com essa consulta temos todo o dataset (Colunas e Linhas).
pd.read_sql(consulta_1, cnn)
# Out:
#      index  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        0            6      148             72             35        0  33.6
# 1        1            1       85             66             29        0  26.6
# 2        2            8      183             64              0        0  23.3
# 3        3            1       89             66             23       94  28.1
# 4        4            0      137             40             35      168  43.1
# ..     ...          ...      ...            ...            ...      ...   ...
# 763    763           10      101             76             48      180  32.9
# 764    764            2      122             70             27        0  36.8
# 765    765            5      121             72             23      112  26.2
# 766    766            1      126             60              0        0  30.1
# 767    767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 10 columns]

# %%
#Selecionando paciente que tem nível de Glucose > 190

consulta_2 = """ 

SELECT
  Age AS 'Idade',
  Glucose AS 'Nível de Glicose',
  Outcome AS 'Resultado'
FROM
  diabetes
WHERE Glucose > 190
"""
pd.read_sql(consulta_2, cnn)
# Out:
#     Idade  Nível de Glicose  Resultado
# 0      53               197          1
# 1      41               196          1
# 2      41               194          1
# 3      57               196          1
# 4      31               197          0
# 5      24               193          0
# 6      34               191          0
# 7      59               194          1
# 8      29               196          1
# 9      25               193          1
# 10     39               197          1
# 11     67               194          0
# 12     55               195          1
# 13     28               198          1
# 14     62               197          1
# 15     22               199          1
# 16     31               195          1

# %%
#Criando uma tabela vazia no BD chamada 'pacientes'


consulta_3 = """
CREATE TABLE pacientes (Pregnancies INT,
                        Glucose INT,
                        BloodPressure INT,
                        SkinThickness INT,
                        Insulin INT,
                        BMI FLOAT,
                        DiabetesPedigreeFunction FLOAT,
                        Age INT,
                        Outcome INT)
"""
pd.read_sql(consulta_3, cnn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1724         try:
# -> 1725             cur.execute(*args, **kwargs)
#    1726             return cur
#
# OperationalError: table pacientes already exists
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-10-b653fd1375bb> in <module>
#      13                         Outcome INT)
#      14 """
# ---> 15 pd.read_sql(consulta_3, cnn)
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     493
#     494     if isinstance(pandas_sql, SQLiteDatabase):
# --> 495         return pandas_sql.read_query(
#     496             sql,
#     497             index_col=index_col,
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1769
#    1770         args = _convert_params(sql, params)
# -> 1771         cursor = self.execute(*args)
#    1772         columns = [col_desc[0] for col_desc in cursor.description]
#    1773
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1735
#    1736             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1737             raise ex from exc
#    1738
#    1739     @staticmethod
#
# DatabaseError: Execution failed on sql '
# CREATE TABLE pacientes (Pregnancies INT,
#                         Glucose INT,
#                         BloodPressure INT,
#                         SkinThickness INT,
#                         Insulin INT,
#                         BMI FLOAT,
#                         DiabetesPedigreeFunction FLOAT,
#                         Age INT,
#                         Outcome INT)
# ': table pacientes already exists

# %%
#Visualizando a tabela pacientes, recém criada.

consulta_4 = """

SELECT
  *
FROM
  pacientes
"""
pd.read_sql(consulta_4, cnn)
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
#Povoando a tabela , através de um Select feito da tabela 'diabetes'. Para pacientes maiores de 50 anos.

consulta_5 = """

INSERT INTO pacientes ( Pregnancies,
                        Glucose,
                        BloodPressure,
                        SkinThickness,
                        Insulin,
                        BMI,
                        DiabetesPedigreeFunction,
                        Age,
                        Outcome)

SELECT
  Pregnancies,
  Glucose,
  BloodPressure,
  SkinThickness,
  Insulin,
  BMI,
  DiabetesPedigreeFunction,
  Age,
  Outcome
FROM
  diabetes
WHERE Age > 50; 
"""
pd.read_sql(consulta_5, cnn)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-ff9191145896> in <module>
#      27 WHERE Age > 50;
#      28 """
# ---> 29 pd.read_sql(consulta_5, cnn)
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     493
#     494     if isinstance(pandas_sql, SQLiteDatabase):
# --> 495         return pandas_sql.read_query(
#     496             sql,
#     497             index_col=index_col,
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1770         args = _convert_params(sql, params)
#    1771         cursor = self.execute(*args)
# -> 1772         columns = [col_desc[0] for col_desc in cursor.description]
#    1773
#    1774         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable

# %%
#Visualizando a tabela 'pacientes'
consulta_6 = """

SELECT
  *
FROM
  pacientes
"""
pd.read_sql(consulta_6, cnn)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             2      197             70             45      543  30.5
# 1             8      125             96              0        0   0.0
# 2            10      139             80              0        0  27.1
# 3             1      189             60             23      846  30.1
# 4             5      166             72             19      175  25.8
# ..          ...      ...            ...            ...      ...   ...
# 76            5       97             76             27        0  35.6
# 77            2      105             75              0        0  23.3
# 78            0      123             72              0        0  36.3
# 79            6      190             92              0        0  35.5
# 80           10      101             76             48      180  32.9
#
#     DiabetesPedigreeFunction  Age  Outcome
# 0                      0.158   53        1
# 1                      0.232   54        1
# 2                      1.441   57        0
# 3                      0.398   59        1
# 4                      0.587   51        1
# ..                       ...  ...      ...
# 76                     0.378   52        1
# 77                     0.560   53        0
# 78                     0.258   52        1
# 79                     0.278   66        1
# 80                     0.171   63        0
#
# [81 rows x 9 columns]

# %%
#Quantidade de pacientes acima dos 50 anos

consulta_7 = """

SELECT count(*) FROM pacientes
"""
pd.read_sql(consulta_7, cnn)
# Out:
#    count(*)
# 0        81

# %%
#Adicionando a caluna 'Perfil' na tabela pacientes, que irá receber a classificação de Obesidade

consulta_8 = """

ALTER TABLE pacientes
ADD Perfil VARCHAR (10)
"""
pd.read_sql(consulta_8, cnn)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-36ab3e8871d0> in <module>
#       6 ADD Perfil VARCHAR (10)
#       7 """
# ----> 8 pd.read_sql(consulta_8, cnn)
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     493
#     494     if isinstance(pandas_sql, SQLiteDatabase):
# --> 495         return pandas_sql.read_query(
#     496             sql,
#     497             index_col=index_col,
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1770         args = _convert_params(sql, params)
#    1771         cursor = self.execute(*args)
# -> 1772         columns = [col_desc[0] for col_desc in cursor.description]
#    1773
#    1774         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable

# %%
#Verificando se foi criado a conluna 'Perfil'
consulta_9 = """

SELECT
  *
FROM
  pacientes
LIMIT (10)
"""
pd.read_sql(consulta_9, cnn)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      197             70             45      543  30.5
# 1            8      125             96              0        0   0.0
# 2           10      139             80              0        0  27.1
# 3            1      189             60             23      846  30.1
# 4            5      166             72             19      175  25.8
# 5           11      143             94             33      146  36.6
# 6           13      145             82             19      110  22.2
# 7            5      109             75             26        0  36.0
# 8            4      111             72             47      207  37.1
# 9            9      171            110             24      240  45.4
#
#    DiabetesPedigreeFunction  Age  Outcome Perfil
# 0                     0.158   53        1   None
# 1                     0.232   54        1   None
# 2                     1.441   57        0   None
# 3                     0.398   59        1   None
# 4                     0.587   51        1   None
# 5                     0.254   51        1   None
# 6                     0.245   57        0   None
# 7                     0.546   60        0   None
# 8                     1.390   56        1   None
# 9                     0.721   54        1   None

# %%
#Inserindo registros na coluna 'Perfil' atributo 'Normal' pra uma determinada condição

consulta_10 = """

UPDATE pacientes
SET Perfil = 'Normal'
WHERE BMI < 30;





"""
pd.read_sql(consulta_10, cnn)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-8f9ac8808016> in <module>
#      12
#      13 """
# ---> 14 pd.read_sql(consulta_10, cnn)
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     493
#     494     if isinstance(pandas_sql, SQLiteDatabase):
# --> 495         return pandas_sql.read_query(
#     496             sql,
#     497             index_col=index_col,
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1770         args = _convert_params(sql, params)
#    1771         cursor = self.execute(*args)
# -> 1772         columns = [col_desc[0] for col_desc in cursor.description]
#    1773
#    1774         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable

# %%
#Verificando se foram inserido os registros na coluna 'Perfil'
consulta_11 = """
SELECT
  *
FROM
  pacientes
LIMIT (10)
"""
pd.read_sql(consulta_11, cnn)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      197             70             45      543  30.5
# 1            8      125             96              0        0   0.0
# 2           10      139             80              0        0  27.1
# 3            1      189             60             23      846  30.1
# 4            5      166             72             19      175  25.8
# 5           11      143             94             33      146  36.6
# 6           13      145             82             19      110  22.2
# 7            5      109             75             26        0  36.0
# 8            4      111             72             47      207  37.1
# 9            9      171            110             24      240  45.4
#
#    DiabetesPedigreeFunction  Age  Outcome  Perfil
# 0                     0.158   53        1    None
# 1                     0.232   54        1  Normal
# 2                     1.441   57        0  Normal
# 3                     0.398   59        1    None
# 4                     0.587   51        1  Normal
# 5                     0.254   51        1    None
# 6                     0.245   57        0  Normal
# 7                     0.546   60        0    None
# 8                     1.390   56        1    None
# 9                     0.721   54        1    None

# %%
#Inserindo registros na coluna 'Perfil' atributo 'Obeso' pra uma determinada condição
consulta_12 = """

UPDATE pacientes
SET Perfil = 'Obeso'
WHERE BMI >= 30;





"""
pd.read_sql(consulta_12, cnn)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-f8d744bbf1c0> in <module>
#      10
#      11 """
# ---> 12 pd.read_sql(consulta_12, cnn)
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     493
#     494     if isinstance(pandas_sql, SQLiteDatabase):
# --> 495         return pandas_sql.read_query(
#     496             sql,
#     497             index_col=index_col,
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1770         args = _convert_params(sql, params)
#    1771         cursor = self.execute(*args)
# -> 1772         columns = [col_desc[0] for col_desc in cursor.description]
#    1773
#    1774         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable

# %%
#Verificando se foram inserido os registros na coluna 'Perfil'
consulta_13 = """
SELECT
  *
FROM
  pacientes
LIMIT (10)
"""
pd.read_sql(consulta_13, cnn)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      197             70             45      543  30.5
# 1            8      125             96              0        0   0.0
# 2           10      139             80              0        0  27.1
# 3            1      189             60             23      846  30.1
# 4            5      166             72             19      175  25.8
# 5           11      143             94             33      146  36.6
# 6           13      145             82             19      110  22.2
# 7            5      109             75             26        0  36.0
# 8            4      111             72             47      207  37.1
# 9            9      171            110             24      240  45.4
#
#    DiabetesPedigreeFunction  Age  Outcome  Perfil
# 0                     0.158   53        1   Obeso
# 1                     0.232   54        1  Normal
# 2                     1.441   57        0  Normal
# 3                     0.398   59        1   Obeso
# 4                     0.587   51        1  Normal
# 5                     0.254   51        1   Obeso
# 6                     0.245   57        0  Normal
# 7                     0.546   60        0   Obeso
# 8                     1.390   56        1   Obeso
# 9                     0.721   54        1   Obeso

# %%
#Criando um cursor que irá armazenar a nossa consulta SQL

cursor = cnn.execute ('SELECT * FROM pacientes')

# %%
#Criando um Loop para selecionar todas as colunas da tabela 'pacientes' e armazenar em uma lista

colunas = [coluna[0] for coluna in cursor.description]
colunas
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome',
#  'Perfil']

# %%
#Criando o DataFrame pra depois geramos um arquivo CSV

resultado = pd.DataFrame.from_records( data = cursor.fetchall(), columns = colunas)

# %%
#Verificando o Shape do DataFrame 'resultado'
resultado.shape
# Out:
# (81, 10)

# %%
#Visualizando as 10 primeiras linhas do DF

resultado.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      197             70             45      543  30.5
# 1            8      125             96              0        0   0.0
# 2           10      139             80              0        0  27.1
# 3            1      189             60             23      846  30.1
# 4            5      166             72             19      175  25.8
# 5           11      143             94             33      146  36.6
# 6           13      145             82             19      110  22.2
# 7            5      109             75             26        0  36.0
# 8            4      111             72             47      207  37.1
# 9            9      171            110             24      240  45.4
#
#    DiabetesPedigreeFunction  Age  Outcome  Perfil
# 0                     0.158   53        1   Obeso
# 1                     0.232   54        1  Normal
# 2                     1.441   57        0  Normal
# 3                     0.398   59        1   Obeso
# 4                     0.587   51        1  Normal
# 5                     0.254   51        1   Obeso
# 6                     0.245   57        0  Normal
# 7                     0.546   60        0   Obeso
# 8                     1.390   56        1   Obeso
# 9                     0.721   54        1   Obeso

# %%
#Gerando o arquivo CSV para passar o projeto a diante!

resultado.to_csv('/content/pacientes.csv', index = False)
